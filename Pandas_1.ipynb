# %% [markdown]
# <a href="https://colab.research.google.com/github/msarkar92/pandas-basics/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Out:
# --2025-10-29 16:06:04--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.239.15.40, 18.239.15.127, 18.239.15.11, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.239.15.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72602133 (69M) [application/zip]
# Saving to: ‘zomato_dataset.zip’
#
# zomato_dataset.zip  100%[===================>]  69.24M  23.5MB/s    in 3.0s
#
# 2025-10-29 16:06:08 (23.5 MB/s) - ‘zomato_dataset.zip’ saved [72602133/72602133]

# %%
# !unzip zomato_dataset.zip
# Out:
# Archive:  zomato_dataset.zip
#   inflating: zomato_dataset.csv

# %%
import pandas as pd

# %%
pd.read_csv("zomato_dataset.csv")
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#a = np.array([1,2,3])

# %%
df = pd.read_csv("zomato_dataset.csv")

# %%
#pd.read_

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Series

# %%
s1 = pd.Series(["Lokesh","Arun","litesh","sandeep","naina"])
s1
# Out:
# 0     Lokesh
# 1       Arun
# 2     litesh
# 3    sandeep
# 4      naina
# dtype: object

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1 = pd.Series(["Lokesh","Arun","litesh","sandeep","naina"],index=["a","b","c","d","e"],name="students")
s1
# Out:
# a     Lokesh
# b       Arun
# c     litesh
# d    sandeep
# e      naina
# Name: students, dtype: object

# %%
s2 = pd.Series(["salaj","gajapathi","palash","sowjanya","sulthan"],index=["a","b","c","d","e"],name="students")
s2
# Out:
# a        salaj
# b    gajapathi
# c       palash
# d     sowjanya
# e      sulthan
# Name: students, dtype: object

# %%
s3 = pd.Series(["salaj","gajapathi","palash","sowjanya","sulthan"],index=range(1,6),name="students")
s3
# Out:
# 1        salaj
# 2    gajapathi
# 3       palash
# 4     sowjanya
# 5      sulthan
# Name: students, dtype: object

# %%
df1 = pd.concat([s1,s2])
df1
# Out:
# a       Lokesh
# b         Arun
# c       litesh
# d      sandeep
# e        naina
# a        salaj
# b    gajapathi
# c       palash
# d     sowjanya
# e      sulthan
# Name: students, dtype: object

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df1 = pd.concat([s1,s2],axis=1)
df1
# Out:
#   students   students
# a   Lokesh      salaj
# b     Arun  gajapathi
# c   litesh     palash
# d  sandeep   sowjanya
# e    naina    sulthan

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Basic

# %% [markdown]
# Head

# %%
df.head() # top 5 rows
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.head(2) # top 2 rows
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# ...

# %% [markdown]
# # tail

# %%
df.tail(2) # last 2 rows
# Out:
#                                                      url  \
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 23191                                            Bhagini           No
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table    rate  votes         phone                    location  \
# 23191         No  2.5 /5     81  080 65951222                  Whitefield
# 23192        Yes  4.3 /5    236  080 49652769  ITPL Main Road, Whitefield
#
#                 rest_type                    dish_liked  \
# 23191  Casual Dining, Bar          Biryani, Andhra Meal
# 23192                 Bar  Cocktails, Pizza, Buttermilk
#
# ...

# %% [markdown]
# # info()

# %%
df.info() # how many null values your dat has
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   rate                         23193 non-null  object
#  6   votes                        23193 non-null  int64
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  object
# ...

# %%
int 23, 24
float 2.5, 6.3
object chtpr87- int+float+str+special
dateandtime
# Out:
# int

# %%
col -237462389324,235345,345,346,36345,345,3453,4534,5345345,556-778-555

# %%
df.describe() # only by default gives you info of numeric column
# Out:
#               votes
# count  23193.000000
# mean     601.074462
# std     1114.854301
# min        0.000000
# 25%      101.000000
# 50%      221.000000
# 75%      586.000000
# max    16832.000000

# %% [markdown]
# shape ,size

# %%
df.shape
# Out:
# (23193, 17)

# %% [markdown]
# # **Accesing just one column**

# %% [markdown]
# 1.   Dot notation: df.column_name
#
# 2.   Bracket notation: df["column_name"]

# %%
df.address
# Out:
# 0        942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1        2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2        1112, Next to KIMS Medical College, 17th Cross...
# 3        1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4        10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#                                ...
# 23188    2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 23189    Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 23190    Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 23191    139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23192    Sheraton Grand Bengaluru Whitefield Hotel & Co...
# Name: address, Length: 23193, dtype: object

# %%
df.votes
# Out:
# 0        775
# 1        787
# 2        918
# 3         88
# 4        166
#         ...
# 23188    128
# 23189     77
# 23190    161
# 23191     81
# 23192    236
# Name: votes, Length: 23193, dtype: int64

# %%
df['votes']
# Out:
# 0        775
# 1        787
# 2        918
# 3         88
# 4        166
#         ...
# 23188    128
# 23189     77
# 23190    161
# 23191     81
# 23192    236
# Name: votes, Length: 23193, dtype: int64

# %%
df.approx_cost(for two people)
# Out:
#   File "/tmp/ipython-input-3016036167.py", line 1
#     df.approx_cost(for two people)
#                    ^
# SyntaxError: invalid syntax

# %%
df['approx_cost(for two people)']
# Out:
# 0         '800.0'
# 1         '800.0'
# 2         '800.0'
# 3         '300.0'
# 4         '600.0'
#            ...
# 23188    '1200.0'
# 23189    '2000.0'
# 23190    '1200.0'
# 23191     '800.0'
# 23192    '2500.0'
# Name: approx_cost(for two people), Length: 23193, dtype: object

# %%
df[["address","votes","names"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2221517054.py in <cell line: 0>()
# ----> 1 df[["address","votes","names"]]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
df[["address","votes","name"]]
# Out:
#                                                  address  votes  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...    775
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...    787
# 2      1112, Next to KIMS Medical College, 17th Cross...    918
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...     88
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...    166
# ...                                                  ...    ...
# 23188  2nd Floor, Iona, Virginia Mall, Whitefield Mai...    128
# 23189  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...     77
# 23190  Keys Hotel, 6, 1st Phase Industrial Area, Near...    161
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...     81
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...    236
#
#                                                     name
# 0                                                  Jalsa
# 1                                         Spice Elephant
# ...

# %% [markdown]
# # Rename

# %%
#df.rename(columns={old:new})
df.rename(columns={"approx_cost(for two people)":"cost_for_2","cuisines":"cuis"})
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#df = df.rename(columns={"approx_cost(for two people)":"cost_for_2","cuisines":"cuis"})
df.rename(columns={"approx_cost(for two people)":"cost_for_2","cuisines":"cuis"}, inplace=True)

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# Adding a column , Deleting a column

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
"AKASH"[:3]
#01234
# Out:
# 'AKA'

# %%
"AKASH"[:-2]
#01234
# Out:
# 'AKA'

# %%
df['rate'].str[:-2]
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 23188    3.8
# 23189    3.9
# 23190    2.8
# 23191    2.5
# 23192    4.3
# Name: rate, Length: 23193, dtype: object

# %%
df['only_rate'] = df['rate'].str[:-2]

# %%
df['only_rate_option2'] = df['rate'].str[:-2] #option

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              23193 non-null  object
#  1   address          23193 non-null  object
#  2   name             23193 non-null  object
#  3   online_order     23193 non-null  object
#  4   book_table       23193 non-null  object
#  5   rate             23193 non-null  object
#  6   votes            23193 non-null  int64
#  7   phone            23193 non-null  object
#  8   location         23193 non-null  object
#  9   rest_type        23193 non-null  object
#  10  dish_liked       23193 non-null  object
#  11  cuis             23193 non-null  object
#  12  cost_for_2       23193 non-null  object
#  13  reviews_list     23193 non-null  object
#  14  menu_item        23193 non-null  object
#  15  listed_in(type)  23193 non-null  object
# ...

# %%
df['only_rate'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1963435102.py in <cell line: 0>()
# ----> 1 df['only_rate'].astype(float)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
import numpy as np

# %% [markdown]
# option 1

# %%
df["only_rate"] = df["only_rate"].replace('N', np.nan)

# %%
df["only_rate"] = df["only_rate"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              23193 non-null  object
#  1   address          23193 non-null  object
#  2   name             23193 non-null  object
#  3   online_order     23193 non-null  object
#  4   book_table       23193 non-null  object
#  5   rate             23193 non-null  object
#  6   votes            23193 non-null  int64
#  7   phone            23193 non-null  object
#  8   location         23193 non-null  object
#  9   rest_type        23193 non-null  object
#  10  dish_liked       23193 non-null  object
#  11  cuis             23193 non-null  object
#  12  cost_for_2       23193 non-null  object
#  13  reviews_list     23193 non-null  object
#  14  menu_item        23193 non-null  object
#  15  listed_in(type)  23193 non-null  object
# ...

# %%
df["only_rate_option2"] = pd.to_numeric(df['only_rate_option2'],errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   url                23193 non-null  object
#  1   address            23193 non-null  object
#  2   name               23193 non-null  object
#  3   online_order       23193 non-null  object
#  4   book_table         23193 non-null  object
#  5   rate               23193 non-null  object
#  6   votes              23193 non-null  int64
#  7   phone              23193 non-null  object
#  8   location           23193 non-null  object
#  9   rest_type          23193 non-null  object
#  10  dish_liked         23193 non-null  object
#  11  cuis               23193 non-null  object
#  12  cost_for_2         23193 non-null  object
#  13  reviews_list       23193 non-null  object
#  14  menu_item          23193 non-null  object
#  15  listed_in(type)    23193 non-null  object
# ...

# %%
df["only_rate_option2"] * 100
# Out:
# 0        410.0
# 1        410.0
# 2        380.0
# 3        370.0
# 4        380.0
#          ...
# 23188    380.0
# 23189    390.0
# 23190    280.0
# 23191    250.0
# 23192    430.0
# Name: only_rate_option2, Length: 23193, dtype: float64

# %%
pd.to_numeric([1,2,True,np.nan])
# Out:
# array([ 1.,  2.,  1., nan])

# %%
help(pd.to_numeric)
# Out:
# Help on function to_numeric in module pandas.core.tools.numeric:
#
# to_numeric(arg, errors: 'DateTimeErrorChoices' = 'raise', downcast: "Literal['integer', 'signed', 'unsigned', 'float'] | None" = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>)
#     Convert argument to a numeric type.
#
#     The default return dtype is `float64` or `int64`
#     depending on the data supplied. Use the `downcast` parameter
#     to obtain other dtypes.
#
#     Please note that precision loss may occur if really large numbers
#     are passed in. Due to the internal limitations of `ndarray`, if
#     numbers smaller than `-9223372036854775808` (np.iinfo(np.int64).min)
#     or larger than `18446744073709551615` (np.iinfo(np.uint64).max) are
#     passed in, it is very likely they will be converted to float so that
#     they can be stored in an `ndarray`. These warnings apply similarly to
#     `Series` since it internally leverages `ndarray`.
#
#     Parameters
#     ----------
# ...

# %% [markdown]
# Delete

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.drop("only_rate_option2") # default the axis -0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2860645927.py in <cell line: 0>()
# ----> 1 df.drop("only_rate_option2")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.drop(2) # default the axis -0
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# 5      https://www.zomato.com/bangalore/timepass-dinn...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %%
df.drop("only_rate_option2",axis=1) # default the axis -0
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.drop("only_rate_option2",axis=1,inplace=True) # default the axis -0

# %% [markdown]
# unique

# %%
df['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Jayanagar', 'Kumaraswamy Layout',
#        'Rajarajeshwari Nagar', 'Mysore Road', 'Uttarahalli',
#        'South Bangalore', 'Vijay Nagar', 'Bannerghatta Road', 'JP Nagar',
#        'BTM', 'Wilson Garden', 'Koramangala 5th Block', 'Shanti Nagar',
#        'Richmond Road', 'City Market', 'Bellandur', 'Sarjapur Road',
#        'Marathahalli', 'HSR', 'Old Airport Road', 'Indiranagar',
#        'Koramangala 1st Block', 'East Bangalore', 'MG Road',
#        'Brigade Road', 'Lavelle Road', 'Church Street', 'Ulsoor',
#        'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road', 'Domlur',
#        'Koramangala 8th Block', 'Frazer Town', 'Ejipura', 'Vasanth Nagar',
#        'Jeevan Bhima Nagar', 'Old Madras Road', 'Commercial Street',
#        'Koramangala 6th Block', 'Majestic', 'Langford Town',
#        'Koramangala 7th Block', 'Brookefield', 'Whitefield',
# ...

# %%
len(df['location'].unique())
# Out:
# 88

# %%
df['location'].value_counts()
# Out:
# location
# Koramangala 5th Block    1783
# BTM                      1456
# Indiranagar              1350
# HSR                      1162
# Jayanagar                1037
#                          ...
# Kanakapura Road             2
# West Bangalore              2
# Yelahanka                   2
# Magadi Road                 2
# KR Puram                    1
# Name: count, Length: 88, dtype: int64

# %%
"sivananndi"[:-1]
# Out:
# 'sivanannd'

# %%
4.5[:-1]
# Out:
# <>:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# /tmp/ipython-input-1052940577.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   4.5[:-1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1052940577.py in <cell line: 0>()
# ----> 1 4.5[:-1]
#
# TypeError: 'float' object is not subscriptable

# %%
Co-relation Question From Case Study Fr ur reference : Question 10: Calculate the correlation between step count and calories burned.

# %%
there is 1 question on Co-relation in the Case Study. How to find Co-relation- it will be helpful if you can hint or give concept on this

# %%
session1 additional question 10

# %%
data = pd.read_csv("sales.csv")
data
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
data.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.067371e+06  1.067371e+06  824364.000000
# mean   9.938898e+00  4.649388e+00   15324.638504
# std    1.727058e+02  1.235531e+02    1697.464450
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13975.000000
# 50%    3.000000e+00  2.100000e+00   15255.000000
# 75%    1.000000e+01  4.150000e+00   16797.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
price_data = data['Price']
price_data.describe()
# Out:
# count    1.067371e+06
# mean     4.649388e+00
# std      1.235531e+02
# min     -5.359436e+04
# 25%      1.250000e+00
# 50%      2.100000e+00
# 75%      4.150000e+00
# max      3.897000e+04
# Name: Price, dtype: float64

# %%
max= data['Price'].max()
data[data['Price']==max]

# data['Price'].groupby(axis ="Customer ID")
# Out:
#         Invoice StockCode Description  Quantity          InvoiceDate    Price  \
# 748142  C556445         M      Manual        -1  2011-06-10 15:31:00  38970.0
#
#         Customer ID         Country
# 748142      15098.0  United Kingdom

# %%
selected_rows = data[1:5]
selected_rows
# Out:
#   Invoice StockCode                     Description  Quantity  \
# 1  489434    79323P              PINK CHERRY LIGHTS        12
# 2  489434    79323W             WHITE CHERRY LIGHTS        12
# 3  489434     22041    RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232  STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
selected_rows[['Customer ID','Invoice']]
# Out:
#    Customer ID Invoice
# 1      13085.0  489434
# 2      13085.0  489434
# 3      13085.0  489434
# 4      13085.0  489434

# %%
q2Data = pd.DataFrame({'name':["Sam","Roma","Mark"], "profession":['dev','mle','Data scientist'],"gender":['male','female','male'], "age":[21,20,25],"review":['No comments','hardworker','need improvement'],"rating":[10,5,7]})
q2Data
# Out:
#    name      profession  gender  age            review  rating
# 0   Sam             dev    male   21       No comments      10
# 1  Roma             mle  female   20        hardworker       5
# 2  Mark  Data scientist    male   25  need improvement       7

# %%
#Assignment Add Q2
q2Data[q2Data['rating'] >= 6][['profession','gender','age']]
# Out:
#        profession gender  age
# 0             dev   male   21
# 2  Data scientist   male   25

# %%
# Assignment Add Q3

q3Data = {
    'name': ['Mark', 'Ramilla', 'Deb', 'Laxman'],
    'profession': ['dev', 'mle', 'mle', 'hr'],
    'gender': ['male', 'female', 'male', 'male'],
    'age': [21, 20, 30, 27],
    'review': ['need improvement', 'Can be improved', 'Scope of improvement', 'Great'],
    'rating': [10, 5, 7, 9]
}

df3 = pd.DataFrame(q3Data)
df3
# Out:
#       name profession  gender  age                review  rating
# 0     Mark        dev    male   21      need improvement      10
# 1  Ramilla        mle  female   20       Can be improved       5
# 2      Deb        mle    male   30  Scope of improvement       7
# 3   Laxman         hr    male   27                 Great       9

# %%
# df3.info()
df3[(df3['age'] >= 23) & (df3['age'] <= 30)]
# Out:
#      name profession gender  age                review  rating
# 2     Deb        mle   male   30  Scope of improvement       7
# 3  Laxman         hr   male   27                 Great       9

# %%
# Assignment Add Q4
import pandas as pd
df4 = pd.DataFrame({'City\tState': ["Kolkata\tWest Bengal", "Chennai\tTamil Nadu", "Hyderabad\tTelengana", "Bangalore\tKarnataka"]})
df4
# Out:
#             City\tState
# 0  Kolkata\tWest Bengal
# 1   Chennai\tTamil Nadu
# 2  Hyderabad\tTelengana
# 3  Bangalore\tKarnataka

# %%
# type(df4)

splitted_columns = df4['City\tState'].str.split('\t', expand=True)

# splitted_columns =
splitted_columns.rename(columns={0:'City',1:'State'}, inplace=True)

splitted_columns
# Out:
#         City        State
# 0    Kolkata  West Bengal
# 1    Chennai   Tamil Nadu
# 2  Hyderabad    Telengana
# 3  Bangalore    Karnataka

# %%
titanic = pd.read_csv("titanic.csv")
titanic.T.drop_duplicates(keep="first")
# Out:
#                        0          1            2           3          4  \
# survived               1          1            1           0          1
# pclass                 3          1            3           3          2
# sex               female     female       female        male     female
# age                 26.0       38.0         26.0         NaN       14.0
# sibsp                  0          1            0           0          1
# parch                  0          0            0           0          0
# fare               7.925    71.2833        7.925      8.4583    30.0708
# embarked               S          C            S           Q          C
# class              Third      First        Third       Third     Second
# adult_male         False      False        False        True      False
# embark_town  Southampton  Cherbourg  Southampton  Queenstown  Cherbourg
#
#                       5            6          7            8          9
# ...

# %%
titanic.drop_duplicates(keep ="first")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       3  female  26.0      0      0   7.9250        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 3         0       3    male   NaN      0      0   8.4583        Q   Third
# 4         1       2  female  14.0      1      0  30.0708        C  Second
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
#
#    adult_male  embark_town  pclass_1    price  gender
# 0       False  Southampton         3   7.9250  female
# 1       False    Cherbourg         1  71.2833  female
# 3        True   Queenstown         3   8.4583    male
# 4       False    Cherbourg         2  30.0708  female
# 6        True  Southampton         1  51.8625    male
# 8       False  Southampton         3  11.1333  female

# %%
titanic.drop_duplicates(keep ="last")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         1       1  female  38.0      1      0  71.2833        C   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town  pclass_1    price  gender
# 2       False  Southampton         3   7.9250  female
# 5        True   Queenstown         3   8.4583    male
# 6        True  Southampton         1  51.8625    male
# 7       False    Cherbourg         1  71.2833  female
# 8       False  Southampton         3  11.1333  female
# 9       False    Cherbourg         2  30.0708  female
